# %% [markdown]
# <a href="https://colab.research.google.com/github/Mutznch/Projeto1_Felix-Augustus-Motelevicz/blob/main/c_pia_de_avalia_o_individual_ra1_e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instruções:
# Para a realização desta tarefa você precisa fazer uma cópia deste carderno de questões para a sua conta. Você responderá a questão colando no AVA o link para a sua cópia contendo as suas respostas.
#
# Todas as questões precisam ser resolvidas algébrica e computacionalmente. Usando todos os recursos computacionais disponíveis na internet. Mas, você não pode consultar outros seres humanos.
#
# **Não se equeça de preencher seu nome nesta célula:**
# Félix augustus Motelevicz

# %%
#IMPORTAR BIBLIOTECAS
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

#DEFININDO SIMBOLOS
x = sp.Symbol('x')

# %% [markdown]
# 5. Juros compostos em investimentos:
#
# Um investidor aplica R$ 5.000 em uma conta de poupança com uma taxa de juros anual de 6% composta mensalmente. Qual será o saldo da conta após 10 anos? Use a fórmula:
#
# $$
# A(t) = P \cdot (1 + \frac{r}{n})^{n \cdot t}
# $$
#
# onde $A(t)$ é o saldo após $t$ anos, $P$ é o principal investido, $r$ é a taxa de juros anual, $n$ é o número de vezes que os juros são compostos por ano e $t$ é o tempo em anos. Não se esqueça de traçar um gráfico mostrando os juros, ano a ano nos próximos 20 anos.

# %%
def plot_function(f, y0, xl1,xl2,yl1,yl2,tit='Gráfico da função f(x)',x1 = 0, y1 = 0,dot = None):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.plot(x0, y0)
    
    if dot is not None:
      ax.scatter(x1, y1, color='red', label=f'{dot}')
      
      
    plt.legend(loc='upper left')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title(f'{tit}')
    ax.grid()
    ax.set_xlim(xl1, xl2)
    ax.set_ylim(yl1, yl2)
    plt.show()

y1 = 5000*((1+(0.06/12))**(12*10))

print(f"\nJuros após 10 anos: {y1:.2f}")
x0 = np.linspace(0, 20, 100)
f = 5000*((1+(0.06/12))**(12*x))
y0 = 5000*((1+(0.06/12))**(12*x0))
plot_function(f,y0,0,20,0,20000,"Função Juros Compostos",10,y1,"Após 10 anos")
# Out:
# Juros após 10 anos: 9096.98

# %% [markdown]
# # Questão 2
# Usando, a seu critério, as bibliotecas do Python, crie um gráfico para cada uma das funções a seguir. No label do gráfico deverá estar a função impressa com qualidade matemática (latex) e uma label dizendo se a função é crescente ou decrescente.
#
# 1. $4^{x+2} - 2^{x+1} = 12$
#
# 2. $\log_{4}(x^2 - 4) - 2\log_{4}(x - 2) = 0$

# %%
x0 = np.linspace(-10, 10, 100)

def plot_function_2(f, y0, xl1,xl2,yl1,yl2,lab1,lab2):
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.plot(x0, y0)
    
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title(f'{lab1}    {lab2}')
    ax.grid()
    ax.set_xlim(xl1, xl2)
    ax.set_ylim(yl1, yl2)
    plt.show()

f = (4**(x+2))-(2**(x+1))
y0 = (4**(x0+2))-(2**(x0+1))
plot_function_2(f,y0,-10,0,-5,10,"$4^{x+2} - 2^{x+1}$",'Função crescente')

def f(x):
  return np.log((x**2)-4)/np.log(4) - 2*np.log(x-2)/np.log(4)
x0 = np.linspace(-10, 10, 1000)
y0 = f(x0)

plt.plot(x0, y0)
plt.xlabel("x")
plt.ylabel("y")
plt.title("$\log_{4}(x^2-4)-2\log_{4}(x-2)$    Função decrescente")
plt.grid(True)
plt.show
# Out:
# <ipython-input-82-34b402519de6>:20: RuntimeWarning: invalid value encountered in log
#   return np.log((x**2)-4)/np.log(4) - 2*np.log(x-2)/np.log(4)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Questão 3
# Usando o Sympy, ou qualquer outro recurso disponível na internet, escreva, com qualidade matemática, o passo-a-passo algébrico que leva a determinação dos indicados a seguir. Ao final, para cada uma das equações, você deverá traçar um gráfico da função.
#
# 1. $\lim_{x \to 0} \frac{e^{2x} - 1}{\sin(x)}$
#
# 2. $\lim_{x \to 0} \frac{\tan(x) - x}{x^3}$

# %% [markdown]
# 1. $\displaystyle \lim_{x\to 0}\frac{e^{2x}-1}{\sin (x)} = \lim_{x\to 0}\frac{e^{2x}-1}{x\frac{\sin (x)}{x}} = \lim_{x\to 0}\frac{e^{2x}-1}{x} = \lim_{x\to 0}\frac{(e^x-1)(e^x+1)}{\sin (x)}=2\lim_{x\to 0}\frac{e^x-1}{x} = 2\lim_{x\to 0}1=2$<br><br>
# 2. $\displaystyle \lim_{x\to 0}\frac{\tan(x)-x}{x^3}=\lim_{x\to 0}\frac{\frac{\sin(x)}{\cos(x)}-x}{x^3}=\lim_{x\to 0}\frac{\sin(x)-x\cos(x)}{x^3\cos(x)}=$<br>$\displaystyle\lim_{x\to 0}\frac{1}{\cos(x)}.\lim_{x\to 0}\frac{\sin(x)-x\cos(x)}{x^3}=\lim_{x\to 0}\frac{\sin(x)-x\cos(x)}{x^3}=\lim_{x\to 0}\frac{-x\cos(x)-\frac{x^3}{6}+x}{x^3}=\lim_{x\to 0}\frac{-\frac{x(6\,\cos(x)+x^{2}-6)}{6}}{x^{3}}=\lim_{x\to 0}{-\frac{6\cos(x)+x^{2}-6}{6x^2}}=\dfrac{1}{6}\,\lim_{x\to{0}}{-\dfrac{x^{2}+6\,\left(1-2\,\sin^{2}\left(\frac{x}{2}\right)\right)-6}{x^{2}}}=\dfrac{1}{6}\,\lim_{x\to{0}}{-\dfrac{x^{2}-12\,\sin^{2}\left(\frac{x}{2}\right)}{x^{2}}}=\dfrac{1}{6}\,\lim_{x\to{0}}{\dfrac{3 \left(\dfrac{\sin\left(\frac{x}{2}\right)}{\dfrac{x}{2}}\right)^{2}\,x^{2}-x^{2}}{x^{2}}}=\dfrac{1}{6}\,\lim_{x\to{0}}{2}=\dfrac{1}{3}$

# %%
def f1(x0):
  return (np.exp(2*x0)-1)/np.sin(x0)
x0 = np.linspace(9, 10, 1000)
y0 = f1(x0)

plt.plot(x0, y0)
plt.title("funçâo 1")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#NAO SEI PORQUE NÃO IMPRIME
def f2(x0):
  return (np.tan(x0)-x0)/x**3
x0 = np.linspace(-np.pi/2, np.pi/2, 1000)
y0 = f2(x0)

plt.plot(x0, y0)
plt.title("função 2")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-d34523d40b05> in <module>
#       5 y0 = f2(x0)
#       6
# ----> 7 plt.plot(x0, y0)
#       8 plt.title("função 2")
#       9 plt.xlabel("x")
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1688         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689         for line in lines:
# -> 1690             self.add_line(line)
# ...
